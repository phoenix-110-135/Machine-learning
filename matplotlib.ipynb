# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
u = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
n = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']
iris =  pd.read_csv("iris.csv")

# %%
iris.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth species
# 0          5.1         3.5          1.4         0.2  Setosa
# 1          4.9         3.0          1.4         0.2  Setosa
# 2          4.7         3.2          1.3         0.2  Setosa
# 3          4.6         3.1          1.5         0.2  Setosa
# 4          5.0         3.6          1.4         0.2  Setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'species'], dtype='object')

# %%
iris.count()
# Out:
# sepallength    150
# sepalwidth     150
# petallength    150
# petalwidth     150
# species        150
# dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
# plot with pandas

# %%
df = iris.iloc[0:10, 0:]
df
# Out:
#    sepallength  sepalwidth  petallength  petalwidth species
# 0          5.1         3.5          1.4         0.2  Setosa
# 1          4.9         3.0          1.4         0.2  Setosa
# 2          4.7         3.2          1.3         0.2  Setosa
# 3          4.6         3.1          1.5         0.2  Setosa
# 4          5.0         3.6          1.4         0.2  Setosa
# 5          5.4         3.9          1.7         0.4  Setosa
# 6          4.6         3.4          1.4         0.3  Setosa
# 7          5.0         3.4          1.5         0.2  Setosa
# 8          4.4         2.9          1.4         0.2  Setosa
# 9          4.9         3.1          1.5         0.1  Setosa

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
iris.boxplot(by='species')
# Out:
# array([[<Axes: title={'center': 'petallength'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petalwidth'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepallength'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepalwidth'}, xlabel='[species]'>]],
#       dtype=object)

# %%
sns.boxplot(x="species" , y="petallength" , data=iris,color="aqua")
# Out:
# <Axes: xlabel='species', ylabel='petallength'>

# %%
ax = sns.boxplot(data=iris, x = 'species',y = 'petallength')
ax = sns.stripplot(data=iris, x='species', y='petallength', jitter=True, edgecolor='green')

# %%
sns.violinplot(x='species',y='petallength', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petallength'>

# %%
sns.pairplot(iris, hue="species")

# %%
sns.FacetGrid(iris, hue ='species') .map(plt.scatter, 'sepallength','petalwidth').add_legend()
